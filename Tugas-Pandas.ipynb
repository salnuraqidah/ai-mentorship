# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("My Uber Drives - 2016.csv")
data
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %% [markdown]
# ### > Exercise 4

# %% [markdown]
# 1. Find all trips that is greater than 10 miles and originated from New York and Morris

# %%
x = data.loc[(data["MILES*"] > 10 ) & (data["START*"].isin(["New York","Morrisville"]))]
x.reset_index(inplace = True, drop = True)
x
# Out:
#          START_DATE*         END_DATE* CATEGORY*       START*  \
# 0    1/10/2016 15:08   1/10/2016 15:51  Business     New York
# 1    1/12/2016 16:02   1/12/2016 17:00  Business     New York
# 2    2/12/2016 11:14   2/12/2016 11:35  Business  Morrisville
# 3    2/12/2016 15:33   2/12/2016 16:06  Business  Morrisville
# 4    2/14/2016 16:35   2/14/2016 17:02  Business     New York
# 5    5/28/2016 14:35   5/28/2016 15:04  Business  Morrisville
# 6    6/10/2016 15:19   6/10/2016 16:28  Business     New York
# 7    7/14/2016 16:03   7/14/2016 16:34  Business  Morrisville
# 8    7/14/2016 16:39   7/14/2016 20:05  Business  Morrisville
# 9    7/22/2016 15:49   7/22/2016 16:22  Business  Morrisville
# 10   7/27/2016 21:34   7/27/2016 21:57  Business  Morrisville
# 11  10/31/2016 18:47  10/31/2016 19:16  Business  Morrisville
#
#                STOP*  MILES*         PURPOSE*
# 0             Queens    10.8          Meeting
# 1      Queens County    15.1          Meeting
# ...

# %% [markdown]
# ### Exercise 5

# %% [markdown]
# 1. Create a new column with the following condition:\
#     a) >10    : Long Trip\
#     b) 5-10   : Medium Trip\
#     c) <5     : Short Trip

# %%
data["DISTANCE"] = np.where(data["MILES*"] < 5, 'Short Trip', 
         (np.where(data["MILES*"] < 10, 'Medium Trip', 'Long Trip')))
data.head(n=10)
# Out:
#        START_DATE*        END_DATE* CATEGORY*           START*  \
# 0   1/1/2016 21:11   1/1/2016 21:17  Business      Fort Pierce
# 1    1/2/2016 1:25    1/2/2016 1:37  Business      Fort Pierce
# 2   1/2/2016 20:25   1/2/2016 20:38  Business      Fort Pierce
# 3   1/5/2016 17:31   1/5/2016 17:45  Business      Fort Pierce
# 4   1/6/2016 14:42   1/6/2016 15:49  Business      Fort Pierce
# 5   1/6/2016 17:15   1/6/2016 17:19  Business  West Palm Beach
# 6   1/6/2016 17:30   1/6/2016 17:35  Business  West Palm Beach
# 7   1/7/2016 13:27   1/7/2016 13:33  Business             Cary
# 8   1/10/2016 8:05   1/10/2016 8:25  Business             Cary
# 9  1/10/2016 12:17  1/10/2016 12:44  Business          Jamaica
#
#              STOP*  MILES*         PURPOSE*     DISTANCE
# 0      Fort Pierce     5.1   Meal/Entertain  Medium Trip
# 1      Fort Pierce     5.0              NaN  Medium Trip
# 2      Fort Pierce     4.8  Errand/Supplies   Short Trip
# ...

# %%
data.to_csv("Uber Drives add column distance.csv", index = False)
